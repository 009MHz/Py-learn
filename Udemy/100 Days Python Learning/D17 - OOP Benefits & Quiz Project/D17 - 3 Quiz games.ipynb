# %% [markdown]
# # Task Breakdown

# %% [markdown]
# ## Create a model for a question in our quiz
# It might have a text attribute for the question texts, and it might also hold an answer attribute which is going to be the correct answer to that question. These two attributes should be initialized with a value when a new question object is created from this class.
# ![image.png](attachment:bc67aea6-a83a-45aa-be32-93c04fe35e4f.png)
#
# ![image.png](attachment:9c46f2fc-3b3c-42be-a04a-9f76cbf1a1da.png)
#
# Created on Question_model.py
